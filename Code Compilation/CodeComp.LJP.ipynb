# %% [markdown]
# <font size = "10">
# <span style="color:darkblue"> CODE COMPILATION NOTEBOOK </span>

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture ONE </span>
#
# <font size = "3">
#
#
#
#
# Material Covered: Virtual environments, Setting up VE, Installing packages with Terminal

# %%
# Importing Packages (make sure to set kernal too)

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os as os
import statsmodels.api as sm
import statsmodels.formula.api as smf

# the "numPy" library is used for mathematical operations
# the "matplotlib" library is for generating graphs
# the "pandas" library is for manipualting datasets
# the OS or "operating system" library is helpful for managing folders 
# "statsmodels.formula.api" contains functions to estimate models
# "statsmodels.api" contains general-use statistical options

# %%
### Opening datasets with "read_csv"
carfeatures = pd.read_csv('data/features.csv')

### Entering the name of a dataframe produces an output with some rows
carfeatures

### Output data for a single column
carfeatures['cylinders']

### Cross table 
# crosstab counts how many rows fall into categories
# "index" is the category
# "columns" is a custom title
pd.crosstab(index = carfeatures['cylinders'],columns = "How many cars have (x) cylinders", margins_name = "cylinders")

#### Scatterplots
plt.scatter(x=carfeatures['weight'], y=carfeatures['acceleration'])
plt.xlabel("weight")
plt.ylabel("acceleration")
plt.show()

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture TWO </span>
# <font size = "3">
#
#
#
#
# Material Covered: Variables and data types, Basic operations, Lists, Visualizing lists

# %%
### Identify type of object
type(4)

### Print function for seeing multiple things at once
print("greetings")

### Assigning variables; can type name to see variable or do print function
name = "Lucy"

### Basic operations on numbers; remember PEMDAS
print(3*2)
print(3+2)
print(3-2)
print(3/2)
print(3**2)

### Concatenate or "add" strings (example with above string) - use the + symbol 
"My name is" + name

### Lists
list_numbers = [1,2,3,4,5]

### Extracting from list; with lists within lists, pull from first to pull list, then pull from that list
print(list_numbers[0])

### Histogram
list_colors = ["red","yellow","yellow", "green","red"]
plt.hist(x= list_colors)
plt.show()

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture THREE </span>
# <font size = "3">
#
#
#
#
# Material Covered: Mathematical operations, Random variables

# %%
### numPy functions

# log(x) computes the logarithm with base "e" (Euler constant)
# exp(x) compute the Euler constant raised to the power of "x"
# sin(x) computes the sine of x
# cos(x) computes the cosine of x
# In this example, we're substituting x = 1

print(np.log(1))
print(np.exp(1))
print(np.sin(1))
print(np.cos(1))
print(np.sqrt(1))

# Pi 
print(np.pi) 

### Array
vec_a  = np.array([1,2,3])
print(vec_a[0]) #accessing element in array
# scalar to all positions, array operations work with ind. elements in each position
# summary stats 
print(np.mean(vec_a))
print(np.std(vec_a))
print(np.min(vec_a))
print(np.median(vec_a))
print(np.max(vec_a))
vec_a.shape # this function allows us to see the shape of an array

### Vector of random variables

# generated from a normal distribution with
# mean "loc" (location) and standard deviation "scale"
# the number of distinct variabels is "size"

randomvar_a = np.random.normal(loc=0, scale=1, size=10)
print(randomvar_a)

# Seeds

np.random.seed(12345) 

# Can use historgram with random variables as well

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture FOUR </span>
# <font size = "3">
#
#
#
#
# Material Covered: Boleen variables (True/False), If/else statements (Flow Control)

# %%
### Test equality 
"Is this the real life?" == "is this just fantasy?"

### Test for presence with in
keyword = "econ"
sentence = "The Federal Reserve makes forecasts about many economic outcomes"
keyword in sentence

current_month      = "January"
list_summer_months = ["June","July","August"]
print( current_month in list_summer_months)
print ('July' in list_summer_months)

### Testing expressions and numbers 
x = 5
print( x < 5 )
print( x <= 5 )
print( x == 5 )
print( x >= 5 )
print( x > 5 )

### Isinstance to test why type of variable something is 
y = 10.0
print( isinstance(y,int)  )
print( isinstance(y,float) )
print( isinstance(y,str) )

### Testing multiple expressions

age  = 22
# Can this person legally vote in the US?
not (age < 18)

# Is this age between 20 and 30 (including these ages)?
( age >= 20 ) & (age <= 30)

student_status = "freshman" 
# Is the student in the first two years of undergrad?
(student_status == "freshman") | (student_status == "sophomore")

### Flow Control

any_questions2 = "no" 
if any_questions2 == "yes":
    print("Need to give more explanations")

years_in_program = 1

if years_in_program == 1:
    print("This student is a freshman")
elif years_in_program == 2:
    print("This student is a sophomore")
elif years_in_program == 3:
    print("This student is a junior")
else:
    print("This student is a senior")

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture FIVE </span>
# <font size = "3">
#
#
#
#
# Material Covered: Additional operations with lists, Loops

# %%
### More operations with Lists

# Simply type "None"
# None datatype = specifies to py we want that space, but there is nothing in it 
list_answers = [None,None,None]

# Assign values with the command "list_answers[index] = value".
# What's the name of your hometown?
list_answers[0] = "Winston-Salem"

# Append to add values to list 
list_answers.append("hello")
print(list_answers)

### Repeats

# Repeat a single value 30 times
list_two_rep = [7] * 30
# Repeat a list 4 times
list_answers_rep = list_answers * 4 
# Repeat of 8 null values
list_none_rep = [None] * 8 

# len() is a function that counts the number of elements
print(len(list_answers))

### Loops

# Visualizing and describing data we already have with loops: 

carfeatures = pd.read_csv("data/features.csv")
list_vars   = ["acceleration","weight"]
index = 1
for variable_name in list_vars:
    plt.scatter(x= carfeatures[variable_name], y = carfeatures["mpg"])
    plt.ylabel("mpg")
    plt.xlabel(variable_name)
    plt.title("Figure" + str(index))
    plt.show()
    index = index + 1

list_datasets = ["features.csv", "worldbank_wdi_2019.csv"]
for i in list_datasets:
    data = pd.read_csv('data/' + i)  
    print(data.describe())

# making mathematical plots with loops

# MATHEMATICAL OPERATIONS
# Create a list of x-values list_x = [1,2,4,5, ..., 50]
# Start an empty list of y-values with []
list_x = [1,2,4,5,6,7,8,9,10]
list_y = []
# Create an index 
for x in list_x:
    y = x**2 + 2*x
    list_y.append(y)
# Display results visually
print(list_y)
plt.scatter(list_x, list_y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# TO FILL Y VALUES LATER
# Create a list of x-values list_x = [1,2,4,5, ..., 50]
# Create a list of y-values to fill in later
list_x = [1,2,4,5,6,7,8,9,10]
list_y = [None] * len(list_x)
# Create an index 
index = 0
for x in list_x:
    list_y[index] = list_x[index]**2 + 2*list_x[index]
    index = index + 1
# Display results visually
print(list_y)
plt.scatter(list_x, list_y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# ['Winston-Salem', None, None, 'hello']

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture SIX </span>
# <font size = "3">
#
#
#
#
# Material Covered: Simulation studies, Visualizing random variables, subplots, single loops, nested loops

# %%
### Different distributions that are common 

# Set Sample size 
# These produce several common distributions
# A normam with "loc" and standard deviation "5"
# A chi-square with "df" degrees of freedom
# A uniform with values between -3 and 5

n = 10000
vec_normal  = np.random.normal(loc = 7, scale = 5, size = n)
vec_chisqr  = np.random.chisquare(df = 1, size = n)
vec_unif    = np.random.uniform(low = -3,high = 5, size = n)


### Creating Subplots (multiple plots in a row)
# Create a plot with 1 row, 2 columns
# You will create a list of subfigures "list_subfig"
# You can choose whichever name you like
# The option "figsize" indicates the (width,height) of the graph

fig, list_subfig = plt.subplots(1, 2,figsize = (6,3))
# The tight layout option ensures that the axes are not overlapping
plt.tight_layout()

# First Figure
list_subfig[0].hist(x = vec_normal)
list_subfig[0].set_title("Normal Distribution")
list_subfig[0].set_xlabel("Value")
list_subfig[0].set_ylabel("Frequency")

# Second Figure
list_subfig[1].hist(x = vec_unif)
list_subfig[1].set_title("Uniform Distribution")
list_subfig[1].set_xlabel("Value")
list_subfig[1].set_ylabel("Frequency")

# Note:
# Use the set_title() function for the title of subfigures
# Similarly, use "set_xlabel()" and "set_ylabel()"


### Single Loops 

# Use "list(range(n))" to create a list from 0 to (n-1).

n= 10
list_zero_ten = list(range(n))
print(list_zero_ten)

# testing the mean if we draw different samples 

vec_xbar = [None, None, None,None]
sample_size = 100
vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[0] = vec_unif.mean()
vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
vec_xbar[1] = vec_unif.mean()

# mean distribution 

# We will draw random sample "num_simulations" times
# Each time we will create a random vector of size "sample_size"
# In this example we will generate values from a uniform between -2 and 2.

num_simulations = 2000
sample_size     = 100
vec_xbar = [None] * num_simulations
for iteration in range(num_simulations):
    vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
    vec_xbar[iteration] = vec_unif.mean()
plt.hist(vec_xbar)
plt.title("Distribution of Xbar with different simulated samples")
plt.ylabel("Frequency")
plt.xlabel("Values of Xbar")
plt.show()


### Nested Loops

# To evaluate different sample size which just have to write a for-loop within 
# another for-loop

num_simulations = 2000
sample_size_list = [1,10,50,100,200]

for sample_size in sample_size_list:

    # The following command a vector null values, of length "num_simulations"
    vec_xbar = [None] * num_simulations
    
    for iteration in range(num_simulations):
            vec_unif  = np.random.uniform(low = -2, high=2, size = sample_size)
            vec_xbar[iteration] = vec_unif.mean()
    plt.hist(vec_xbar)
    plt.title("Distribution of Xbar when n is " + str(sample_size))
    plt.ylabel("Frequency")
    plt.xlabel("Values of Xbar")
    plt.show()


# Putting all the plots in the same row 

num_simulations = 2000
sample_size_list = [1,10,50,100,200]

fig, list_subfig = plt.subplots(1,len(sample_size_list),figsize = [12,3])
plt.tight_layout()

index = 0
for sample_size in sample_size_list:
    vec_xbar = [None] * num_simulations
    
    for iteration in range(num_simulations):
            vec_chisqr  = np.random.chisquare(df = 1, size = sample_size)
            vec_xbar[iteration] = vec_chisqr.mean()
    list_subfig[index].hist(vec_xbar)
    list_subfig[index].set_title("Distribution of Xbar when n is " + str(sample_size))
    list_subfig[index].set_ylabel("Frequency")
    list_subfig[index].set_xlabel("Values of Xbar")
    index = index + 1


### Double loop example 

list_lower = [93, 90, 87, 83, 80, 77, 73, 70, 67, 63, 60, 0]
list_upper = [100, 92, 89, 86, 82, 79, 76, 72, 69, 66, 62, 59]
list_letters = ["A","A-","B+","B","B-","C+","C","C-","D+","D","D-","F"]  

list_studentgrades = [84, 62, 92, 74, 97, 80, 79]

# solution with range(len)

for studentgrade in list_studentgrades:
    for letter in range(len(list_letters)): 
        if (studentgrade<=list_upper[letter-1])&(studentgrade>=list_lower[letter-1]):
            print("The student got a numeric grade of " + str(studentgrade) + " and their letter grade was " + str(list_letters[letter-1]))

# range(len) --> len = # of spots in the specified list; range turns it into a list [1,2,3,...] for that length 
# must do letter-1 because the list positions start at [0] BUT the range begins at 1 

# solution with index 

for grade in list_studentgrades: 
        index = 0 
        for letter in list_letters: 
                if (grade<=list_upper[index])&(grade>=list_lower[index]):
                    print("The student got a numeric grade of " + str(grade) + " and their letter grade was " + str(list_letters[index])) 
                index=index+1



# Converting CSV files to Excel

list_datasets = ["data_quiz/wdi_ages1980.csv","data_quiz/wdi_ages2000.csv", "data_quiz/wdi_ages2020.csv"]
list_newnames = ["data_excel/ages1980.xlsx", "data_excel/ages2000.xlsx", "data_excel/ages2020.xlsx"]

index=0
for dataset in list_datasets:
    dataset = pd.read_csv(dataset) 
    filename = list_newnames[index]
    dataset.to_excel(filename) 
    index = index + 1

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture SEVEN </span>
# <font size = "3">
#
#
#
#
# Material Covered: Functions, User-defined functions, Custom functions, Lambda functions

# %%
### Argument, Returns, Parameters 

# Here "df" and "size" are both parameters - must include parameters for this function to work
# They get assigned the arguments "2" and "20", respectively
# The return is a vector of random variables

vec_x = np.random.chisquare(df = 10, size = 20)
vec_x

vec_y = np.random.normal(loc = 2, scale = 5, size = 20)
vec_z = np.random.uniform(low = -2, high =2, size = 50)

vec_y: 
# parameters are "loc" "scale" and "size" 
# arguments are the values passing to the function that we want the parameters to take (2, 5, 20)
# return will be a vector of the specified size within the appropriate parameters 
# change the scale from 5 to 1, the numbers in the vector will be closer to 2 

# First Argument:   np.pi     (a numeric value)
# Second Argument:  6         (the number of decimals)
# Return:  Round the first argument, given the number of decimals in the second argument

round(np.pi,  3)

# round function - first argument takes a float, second argument takes how many decimal places you want to round


### Custom Functions

def fn_compute_value (P,r,n,t):
    V = P*((1+(r/n))**(n*t))
    return V 

fn_compute_value(P=100,r=0.01,n=20,t=10)

# my initial solution 
def fn_polynomial (x):
    f=(x**2)+(2*x)+1
    return f
fn_polynomial(3)

# Juan solution - more concise and to the point
def f(x):
    return (x**2)+(2*x)+1
f(2)

def f_num_1(numeric_grade): 
    if numeric_grade >= 50:
        status = 'Pass'
    else: 
        status = 'Fail'
    return status

f_num_1(89)

def f_num(numeric_grade): 
    if numeric_grade>=50:
        return "Pass" 
    else:
        return "Fail"
    
f_num(40)


### Lambda Functions

# in lambda functions, use function lambda, then pass parameters, and save into an object that becomes a function itself in same line

# (a) Define function
fn_sum = lambda x,y,z: x + y + z

# (b) Run function
fn_sum(1,2,3)

# looping + functions
list_ages = [18,29,15,32,6]
for age in list_ages:
    print("A person with age " + str(age) + " can vote: " +
           str(fn_iseligible_vote(age)))
    
# Juan solution 
list_ages_J = [18,29,15,32,6]
result_list = []
for age in list_ages_J: 
    result_list.append(fn_iseligible_vote(age))
print(result_list)
print(np.sum(result_list)) # tells us how many people are able to vote

# boleean + functions
fn_iseligible_vote = lambda age: age>=18 
print(fn_iseligible_vote(21))
print(fn_iseligible_vote(9))

### functions for visualization 

def red_histogram(vec_x,title):
    plt.hist(x = vec_x, color = "red")
    plt.title(title)
    plt.ylabel("Frequency")
    plt.show()

carfeatures = pd.read_csv("data/features.csv")
red_histogram(vec_x = carfeatures["weight"], title = "Histogram")
red_histogram(vec_x = carfeatures["acceleration"], title = "Histogram")

def practice_scatter(vec_x,vec_y, title):
    plt.scatter(x=vec_x,y=vec_y, color="green")
    plt.title(title) 
    plt.xlabel("vec_x")
    plt.ylabel("vec_y")
    plt.show

carfeatures = pd.read_csv("data/features.csv")
practice_scatter(carfeatures["weight"],carfeatures["acceleration"], "weight by acceleration")

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture EIGHT </span>
# <font size = "3">
#
#
#
#
# Material Covered: Local/Global Variables, Apply function, Map function, "os" library functions*
#
# *'os' library functions were in assignment 5

# %%
# when using Boolean variables, use "AND" not "&" 
# and is lazy, & is eager 

### Global Variables 
message_hello = "hello"
number3       = 3
# all the notebook has access to these variables when define them here - they are GLOBAL 

# not ideal to us gloabl in a function - instead make sure parameters are defined WITHIN the function

def fn_add_notrecommended(x,y):
    return(x + y + z)
z = 5
print(fn_add_notrecommended(x = 1, y = 2))
z = 10
print(fn_add_notrecommended(x = 1, y = 2))
# variable z is defined outside the parameters of the function, so if you change z, you might not realize you messed up the code 

### Local Variables 

# ex) paramters and intermediate variables

# This is an example where we define a quadratic function
# (x,y) are both local variables of the function
# 
# When we call the function, only the arguments matter.
# any intermediate value inside the function

def fn_square(x):
    y = x**2
    return(y)

x = 5
y = -5
# defining two global variables that have same name as local variables defined inside the function, but if we pass the local variable, then the function will run the local
# functions prioritize the LOCAL variables NOT global 
print(fn_square(x = 1))

def modify_x():
    global x
    x = x + 5

x = 1 # define global value of x here 
# Now, running the function wil permanently increase x by 5.
modify_x() # this function takes the global x, then adds 5 to it, and permenantly changes the global variable 
print(x)

# local variables are NOT stored in working environment 

### Operations of data frames: Apply function  

data  = pd.DataFrame() #create object that is pandas data frame that is empty 

#adding varaibles to empty data frame 
data["age"]                   = [18,29,15,32,6]
data["num_underage_siblings"] = [0,0,1,1,0]
data["num_adult_siblings"]    = [1,0,0,1,0]

# write functions first 
fn_iseligible_vote = lambda age: age >= 18
fn_istwenties      = lambda age: (age >= 20) & (age < 30)
fn_sum             = lambda x,y: x + y

def fn_agebracket(age):
    if (age >= 18):
        status = "Adult"
    elif (age >= 10) & (age < 18):
        status = "Adolescent"
    else:
        status = "Child"
    return(status)

# once defined functions, THEN can use the apply function 
data["can_vote"]    = data["age"].apply(fn_iseligible_vote)
data["in_twenties"] = data["age"].apply(fn_istwenties)
data["age_bracket"] = data["age"].apply(fn_agebracket)

# NOTE: The following code also works:
# data["can_vote"]    = data["age"].apply(lambda age: age >= 18)
# data["in_twenties"] = data["age"].apply(lambda age: (age >= 20) & (age < 30))

display(data) # another way to show all your data 

### Mapping functions with one or more arguments 

# works with multiple lists; item is sent to function as a parameter and each item can be iterable (like list or array) 

data["can_vote_map"] = list(map(fn_iseligible_vote  , data["age"]))

# more than two arguments: 
data["num_siblings"] = list(map(fn_sum, data["num_underage_siblings"], data["num_adult_siblings"]))
data["num_siblings"]

### Storing files

features = pd.read_csv("data_raw/features.csv")
features['mpg_above_29']=features['mpg'].apply(lambda g: g>=29)
features.to_csv("data_clean/features.csv") #this is the store
pd.read_csv("data_clean/features.csv")

### OS Library functions 

# Current Working Directory (CWD) 

# the get shows current CWD
current_directory = os.getcwd()
print(current_directory)

# this pulls a list of files from the cwd
ls_files = os.listdir(current_directory)
print(ls_files)

# changing cwd to another path - two ways 

os.chdir(current_directory+"/"+ls_files[2]) 
print(os.listdir(os.getcwd()))
print(os.getcwd())

os.chdir(current_directory+"/wdi_data") 
print(os.listdir(os.getcwd()))
print(os.getcwd())

# changing back to OG 

os.chdir(current_directory)
print(os.getcwd())

# storing dataset to another folder 

dataset_name = 'wdi_2000.csv'
old_directory = 'wdi_data/'
new_directory = 'clean_data/'
old_path = old_directory + dataset_name
new_path = new_directory + dataset_name

old = pd.read_csv(old_path)
old.to_csv(new_path)

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture NINE </span>
# <font size = "3">
#
#
#
#
# Material Covered: Subsetting data, basic data display, subsetting by row/column position, filtering dataframes based on logical expressions, visualization for subsets of data, Random things covered in assignment 6

# %%
### Data Display 

display(carfeatures)

# column names 

# use values to transform the sequence of names into an array 
car_colnames = carfeatures.columns.values
# also can use dot
carfeatures.columns
# can also use list to get all the names in that format
columns = list(carfeatures.columns)

# Subset Columns 

list_subsetcols = ["weight","mpg"]
subcols_carfeatures = carfeatures[list_subsetcols]
# Or we can simply include the list directly inside square brackets
display(carfeatures[["weight","mpg"]])
# if want more than one column, must pass as list with names as strings 

### Subsetting by row/column position 

# sort by columns 
carsorted = carfeatures.sort_values(by = "mpg", ascending = False)

# subset rows 
display(carsorted.iloc[0,:])
display(carsorted.iloc[[0,1,2],:])

# subset blocks of rows 

# Extract rows 0 to 5
display(carfeatures.iloc[0:5,:])
# does not show 5 - stops right before then since it is the upper limit 

# Extract rows 8 onwards
display(carfeatures.iloc[ 8:, : ])

# Note: We can leave the numbers to the left and right of ":" blank
# in order to select all values before or after, respectively.

# similar stuff for columns as well: 
# one column: data.iloc[ : , col_integer]
# multiple columns: data.iloc[:, list_cols]

# row + column together: data. iloc[list_rows, list_cols]

### Filtering Dataframes Based on Logical Expressions 

# Option One: square bracket operator 
carfeatures[carfeatures['mpg']>=25]
carfeatures[(carfeatures['acceleration']>= 10) & (carfeatures['acceleration']< 18)]

# Option Two: data.query("logical expression")
carfeatures.query("mpg >= 25")
carfeatures.query("(acceleration >= 10) & (acceleration < 18)")

# for query, must use quotation marks " " in logical expression for it to work 

# want to use the bitwise operator here for these so all positions are evaluated

# expressions with colnames + global variables (@) 

threshold = 25
# two options: 
square_mpg_threshold = carfeatures[carfeatures["mpg"]>=threshold]
data_varthreshold_mpg = carfeatures.query("mpg >= @threshold")

# with column name with spaces must use new symbol for query 
carfeatures["new variable two"] = carfeatures["mpg"]
data_spacesthreshold_mpg_two = carfeatures.query("`new variable two` >= 25")

### Visualization for Subsets of Data

# Use pd.unique() to extract a list with the unique elements in that column
# what specifically is "unique" = is that what values are unique that are present 
list_unique_cylinders = pd.unique(carfeatures["cylinders"])

# overlapping plots 

# If we call plt.scatter() twice to display two plots
# To display all plots simultaneously we include plt.show() at the very end.
# The idea is that the graphs are stacked on top of each other

df_8 = carfeatures.query("cylinders == 8")
df_4 = carfeatures.query("cylinders == 4")

plt.scatter(x = df_8["weight"],y = df_8["acceleration"])
plt.scatter(x = df_4["weight"],y = df_4["acceleration"])
plt.legend(labels = ["8","4"],
           title  = "Cylinders")

plt.show()

# Compute number of unique categories
list_unique_cylinders = pd.unique(carfeatures["cylinders"])

# Use a for loop to plot a scatter plot between "weight" and "acceleration"
# for each category. Each plot  will have a different color

for category in list_unique_cylinders:
    df   = carfeatures.query("cylinders == @category")
    plt.scatter(x = df["weight"],y = df["acceleration"])
    
# Add labels and a legends    
plt.xlabel("Weight")
plt.ylabel("Acceleration")
plt.legend(labels = list_unique_cylinders,
           title  = "Cylinders")
plt.show()

# alpha makes the histogram more transparent 

for category in list_unique_cylinders: 
    cylinder = carfeatures.query('cylinders == @category')
    plt.hist(x=cylinder['mpg'], alpha=0.5)
    
plt.xlabel("mpg")
plt.ylabel("Frequency")
plt.legend(labels = list_unique_cylinders, title = "Cylinders")
plt.show()

### Assignment Six

# upper() converts everything to uppercase letters 

data.upper()

# to get a percentile - ie. here is the 25th 

np.nanpercentile(data['column name'], 25)

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture TEN </span>
# <font size = "3">
#
#
#
#
# Material Covered: Linear regression applications, Statsmodels Library, Generate simulated data, estimated best fit line, errors

# %%
### Basic Linear Regression

# create empty dataset 
dataset = pd.DataFrame()
# create two random variables, e is error
n = 50
np.random.seed(42)
dataset["x"] = np.random.normal(loc = 0,scale = 1, size = n)
dataset["e"] = np.random.normal(loc = 0,scale = 1, size = n)
# create data from linear model 
b0 = 1
b1 = 2
dataset["y"] = b0 + b1 * dataset["x"] + dataset["e"]
# compute the theoretically best fit line 
dataset["p"] = b0 + b1*dataset["x"]
# plot the data 
plt.scatter(x = dataset["x"], y = dataset["y"])
plt.plot(dataset["x"],dataset["p"], color = 'green') # plot or LINE plot - line of best fit 
plt.xlabel("X Variable")
plt.ylabel("Y Variable")
plt.legend(labels = ["Data points", "Best fit line"])
plt.show()

### Other pandas functions: mean and standard deviation  
ybar = dataset["y"].mean()
stdv_sample = dataset["y"].std()

### Estimate the best fit line 

model   = smf.ols(formula = 'y ~  x',data = dataset)
results = model.fit(cov_type = "HC1")

results.summary()
# summary() gives summary of our data 

# compute the estimated best fit line 
b_list = results.params #get the parameters from the results 
dataset["p_estimated"] = b_list[0] + b_list[1]  * dataset["x"]
# plot the best fit line
plt.scatter(x = dataset["x"],y = dataset["y"])
plt.plot(dataset["x"],dataset["p_estimated"], color = 'green')
plt.legend(labels = ["Data points","Estimated Predicted Model"])
plt.show()

### How good is the estimated fit? 

plt.plot(dataset['x'],dataset['p'], "-o", color="blue")
plt.plot(dataset['x'], dataset['p_estimated'], "-o",  color = "green") 
plt.legend(labels = ["Real Model", "Estimated Predicted Model"])
plt.show()

# "-o" makes it so data is individual points, without this all we have is a smooth line

# %% [markdown]
# <font size = "5">
# <span style="color:darkgreen"> Lecture ELEVEN </span>
# <font size = "3">
#
#
#
#
# Material Covered: Random Assignment

# %%
# "list_status" is a list with "treatment/control" arms
# "prop_status" is the proportion in the treatment and control arms
# "size_dataset" is how many rows are contained

list_status  = ["Treatment","Control"]
prop_status  = [0.4,0.6]
size_dataset = len(carfeatures)

# The "np.random.choice" will create a vector with the status
# We will save this to a column in "carfeatures"
# Note: (i) We can always split the arguments of a function in multiple lines
#           to make it easier to read

carfeatures["status"] = np.random.choice(list_status,
                                         size = size_dataset,
                                         p = prop_status)

display(carfeatures)

# The command "pd.crosstab" computes frequencies
# If we add the option "normalize" it will compute proportions
# Note: The default assignment is done randomly without replacement
#       which means that the proportions are approximately the same   
#       (but not equal) to "prop_status"

frequency_table   = pd.crosstab(index = carfeatures["status"], columns = "Frequency")
proportions_table = pd.crosstab(index = carfeatures["status"],
                                columns = "Proportion",
                                normalize = True)

display(frequency_table)
display(proportions_table)

# When you have queries for text variables, it's important
# to use outer ' ' single quotations
# and inner double quotations.

data_treated = carfeatures.query('status == "Treatment" ')
data_control = carfeatures.query('status == "Control" ')

# The count is different because we assigned different proportions
# All other sumary statistics are approximately the same
# They are not identical because the assignment is random

display(data_treated.describe())
display(data_control.describe())
